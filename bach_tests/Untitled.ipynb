# %%
from music21 import *
# %load_ext music21.ipython21

# %%
chorales = corpus.getBachChorales('xml')

# %%
s = corpus.parse(chorales[10])
s.show('musicxml')

# %%
post = s.measure(10)
#post = s.beatAndMeasureFromOffset(5)
a = analysis.discrete.KrumhanslSchmuckler()
a.process(post, storeAlternatives=True)

#post.show('musicxml')
a.getSolutionsUsed(), a.alternativeSolutions
#print(s.beatAndMeasureFromOffset(5))
#dir(post)
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accumulatedSeconds',
#  '_activeSite',
#  '_activeSiteStoredOffset',
#  '_addElementPreProcess',
#  '_adjacencySearch',
#  '_appendCore',
#  '_atSoundingPitch',
#  '_cache',
#  '_classListCacheDict',
#  '_classListFullyQualifiedCacheDict',
#  '_classSetCacheDict',
#  '_consolidateLayering',
#  '_deepcopySubclassable',
#  '_derivation',
#  '_durSpanOverlap',
#  '_duration',
#  '_elements',
# ...

# %%
c = s.chordify()
#c=c.flat.notes

# %%
b = s.measure(10)
#d = b.beatAndMeasureFromOffset(searchOffset=1.5)
d = b.measureOffsetMap()
#d = b.groupElementsByOffset(5)
#d = b.sliceByQuarterLengths(1, inPlace=False, addTies=True)
#d = b.quantize([1], processOffsets=True, processDurations=True, inPlace=False)
list(b.offsetMap()),b.beatAndMeasureFromOffset(searchOffset=0) #dir(b), 
#list(b.sliceByQuarterLengths(.25, inPlace=False, addTies=False))
#d.show('musicxml')
#d = b.sliceAtOffsets([1, 2, 3, 4], inPlace=False)
#d.show('musicxml')
dir(s)
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accumulatedSeconds',
#  '_activeSite',
#  '_activeSiteStoredOffset',
#  '_addElementPreProcess',
#  '_adjacencySearch',
#  '_appendCore',
#  '_atSoundingPitch',
#  '_cache',
#  '_classListCacheDict',
#  '_classListFullyQualifiedCacheDict',
#  '_classSetCacheDict',
#  '_consolidateLayering',
#  '_deepcopySubclassable',
#  '_derivation',
#  '_durSpanOverlap',
#  '_duration',
#  '_elements',
# ...

# %%
a.process(b, storeAlternatives=True)
# Out:
# ((<music21.pitch.Pitch A>, 'minor', 0.8901744442622779), '#57369b')

# %%
b.show('text')
# Out:
# {0.0} <music21.stream.Part Cornet 1>
#     {0.0} <music21.instrument.Instrument P1: Cornet 1: Instrument 5>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.Key of G major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 10 offset=0.0>
#         {0.0} <music21.note.Note A>
#         {0.75} <music21.note.Note B>
#         {1.0} <music21.note.Note B>
#         {2.0} <music21.note.Note A>
#         {3.0} <music21.note.Note A>
# {0.0} <music21.stream.Part Cornet 2>
#     {0.0} <music21.instrument.Instrument P2: Cornet 2: Instrument 6>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.Key of G major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 10 offset=0.0>
#         {0.0} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#         {3.0} <music21.note.Note D>
# {0.0} <music21.stream.Part Oboe>
#     {0.0} <music21.instrument.Instrument P3: Oboe: Instrument 7>
# ...

# %%
from music21.figuredBass import checker

# %%
allHarmonies = checker.extractHarmonies(s)

# %%
s1 = stream.Stream()
for (offsets, notes) in sorted(allHarmonies.items()):
    
    print(offsets, notes)
    for n in notes:
        if not n.isNote:
            notes.remove(n)
    s1.append(chord.Chord(notes))
s1.show('musicxml')
# Out:
# (0.0, 0.5) [<music21.note.Note B>, <music21.note.Note G>, <music21.note.Note B>]
# (0.5, 1.0) [<music21.note.Note D>, <music21.note.Note A>, <music21.note.Note C>]
# (1.0, 1.5) [<music21.note.Note B>, <music21.note.Note G>, <music21.note.Note D>]
# (1.5, 2.0) [<music21.note.Note B>, <music21.note.Note G>, <music21.note.Note D>]
# (2.0, 3.0) [<music21.note.Note C>, <music21.note.Note G>, <music21.note.Note E>]
# (3.0, 4.0) [<music21.note.Note A>, <music21.note.Note D>, <music21.note.Note A>]
# (4.0, 4.5) [<music21.note.Note A>, <music21.note.Note C>, <music21.note.Note A>]
# (4.5, 5.0) [<music21.note.Note A>, <music21.note.Note C>, <music21.note.Note A>]
# (5.0, 5.5) [<music21.note.Note B>, <music21.note.Note G>, <music21.note.Note D>]
# (5.5, 6.0) [<music21.note.Note B>, <music21.note.Note G>, <music21.note.Note D>]
# (6.0, 6.5) [<music21.note.Note D>, <music21.note.Note A>, <music21.note.Note D>]
# (6.5, 7.0) [<music21.note.Note D>, <music21.note.Note A>, <music21.note.Note D>]
# ...

# %%
dir(checker)
# Out:
# ['Test',
#  '_DOC_ORDER',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'checkConsecutivePossibilities',
#  'checkSinglePossibilities',
#  'collections',
#  'copy',
#  'correlateHarmonies',
#  'createOffsetMapping',
#  'extractHarmonies',
#  'generalNoteToPitch',
#  'getVoiceLeadingMoments',
#  'hiddenFifth',
#  'hiddenFifthsTable',
#  'hiddenOctave',
#  'hiddenOctavesTable',
#  'opFrac',
#  'parallelFifths',
#  'parallelFifthsTable',
#  'parallelOctaves',
#  'parallelOctavesTable',
#  'possibility',
#  'stream',
#  'unittest',
#  'voiceCrossing',
#  'voiceLeading']
